# %%
import pandas as pd

# %%
city = pd.read_csv(r"C:\Users\eymem\Documents\GitHub\Population-Diversity-Study\city.csv")

# %%
city.head()
# Out:
#    ID            Name CountryCode       District  Population
# 0   1           Kabul         AFG          Kabol     1780000
# 1   2        Qandahar         AFG       Qandahar      237500
# 2   3           Herat         AFG          Herat      186800
# 3   4  Mazar-e-Sharif         AFG          Balkh      127800
# 4   5       Amsterdam         NLD  Noord-Holland      731200

# %%
city.shape
# Out:
# (4079, 5)

# %%
city.dtypes
# Out:
# ID              int64
# Name           object
# CountryCode    object
# District       object
# Population      int64
# dtype: object

# %%
city["Population"].describe()
# Out:
# count    4.079000e+03
# mean     3.504682e+05
# std      7.237757e+05
# min      4.200000e+01
# 25%      1.147890e+05
# 50%      1.670510e+05
# 75%      3.106385e+05
# max      1.050000e+07
# Name: Population, dtype: float64

# %%
city.isna().sum()
# Out:
# ID             0
# Name           0
# CountryCode    0
# District       4
# Population     0
# dtype: int64

# %%
city.dropna(subset=['District'])
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4075 rows x 5 columns]

# %%
city.duplicated().sum()
# Out:
# np.int64(0)

# %%
city.rename(columns={"ID": "CityID", "Name": "City"}, errors="ignore", inplace=True)

# %%
city["City"].value_counts().sort_values(ascending=False)
# Out:
# City
# San Jose        3
# San Fernando    3
# León            3
# Toledo          3
# Richmond        3
#                ..
# Hebron          1
# Jabaliya        1
# Nablus          1
# Kabul           1
# Cumaná          1
# Name: count, Length: 4001, dtype: int64

# %%
city["CountryCode"].value_counts().sort_values(ascending=False)
# Out:
# CountryCode
# CHN    363
# IND    341
# USA    274
# BRA    250
# JPN    248
#       ...
# URY      1
# NCL      1
# VUT      1
# WLF      1
# VIR      1
# Name: count, Length: 232, dtype: int64

# %%
city["District"].value_counts().sort_values(ascending=False)
# Out:
# District
# England         71
# São Paulo       69
# California      68
# Punjab          47
# West Bengali    46
#                 ..
# Béjaïa           1
# Mostaganem       1
# Tébessa          1
# Tlemcen          1
# Béchar           1
# Name: count, Length: 1366, dtype: int64

# %%
city["District"].value_counts().sort_values(ascending=False)
# Out:
# District
# England         71
# São Paulo       69
# California      68
# Punjab          47
# West Bengali    46
#                 ..
# Béjaïa           1
# Mostaganem       1
# Tébessa          1
# Tlemcen          1
# Béchar           1
# Name: count, Length: 1366, dtype: int64

# %%
city_sql = city.to_csv(r"C:\Users\eymem\Documents\GitHub\Population-Diversity-Study\city_sql.csv",index=False)

# %%
city.head()
# Out:
#    CityID            City CountryCode       District  Population
# 0       1           Kabul         AFG          Kabol     1780000
# 1       2        Qandahar         AFG       Qandahar      237500
# 2       3           Herat         AFG          Herat      186800
# 3       4  Mazar-e-Sharif         AFG          Balkh      127800
# 4       5       Amsterdam         NLD  Noord-Holland      731200
